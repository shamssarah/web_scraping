# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
table_tag = soup.findAll(lambda tag: tag.name=='table') 
# rows = table.findAll(lambda tag: tag.name=='tr')

# %%
table_tag[2]
# Out:
# <table border="1" class="wikitable sortable static-row-numbers plainrowheaders srn-white-background" style="text-align:right;">
# <caption>GDP (US$ million) by country
# </caption>
# <tbody><tr class="static-row-header" style="text-align:center;vertical-align:bottom;">
# <th rowspan="2">Country/Territory
# </th>
# <th rowspan="2"><a href="/wiki/United_Nations_geoscheme" title="United Nations geoscheme">Region</a>
# </th>
# <th colspan="2"><a href="/wiki/International_Monetary_Fund" title="International Monetary Fund">IMF</a><sup class="reference" id="cite_ref-GDP_IMF_1-2"><a href="#cite_note-GDP_IMF-1">[1]</a></sup>
# </th>
# <th colspan="2"><a href="/wiki/United_Nations" title="United Nations">United Nations</a><sup class="reference" id="cite_ref-UN_13-0"><a href="#cite_note-UN-13">[12]</a></sup>
# </th>
# ...

# %%
#thead(tr -> td),tbody (tr -> td)

# %%
table = []
column = []
column_no = 1

for t in table_tag:
#     print (t.find("caption"))
#     print ("?????????????????????????",t)
    if (t.find("caption")):
        
        print (t.find("caption"))
#         print(t.find("thead"))
        for i,rows in enumerate(t.findAll("tr")):
#             print ("colspan" in th.attrs)

#             print (i,rows)
            for th in rows.findAll("th"):
                if ("colspan" in th.attrs):
#                     print (th.attrs["colspan"])
                    for _ in range(int(th.attrs["colspan"])):
                        column.append(th.find("a").contents[-1].strip())
                elif (th.find("a")):
    #                 print (th.find("a").contents[0].strip())
                    value = th.find("a").contents[0].strip()
                    column.append(value)
#                     if value not in column: column.append(value)
                else:
    #                 print (">>>",th.contents[0])
                    value = th.contents[0].strip()
                    column.append(value)
#                     if value not in column: column.append (value)
                print (column,i)
            if (i == 0):
                column_no = len(column)
            print (column_no)
            
#             print (i%column_no == 0 and i!=0, i , column_no)      
#             if (i%(column_no) == 0 and i != 0):
                
#                 row = []
            row = []
            for _,td in enumerate (rows.findAll ("td")):
#                 print (td)

                if ("colspan" in td.attrs):
                    for _ in range(int(td.attrs["colspan"])): 
                        row.append(td.contents[0].strip())
                elif (td.find("sup")):
                    row.append(td.contents[-1].strip())
                elif (td.find("a")):
                    row.append(td.find("a").contents[0].strip())
                else:
                    row.append(td.contents[0].strip())
            table.append(row)
# Out:
# <caption>GDP (US$ million) by country
# </caption>
# ['Country/Territory'] 0
# ['Country/Territory', 'Region'] 0
# ['Country/Territory', 'Region', 'IMF', 'IMF'] 0
# ['Country/Territory', 'Region', 'IMF', 'IMF', 'United Nations', 'United Nations'] 0
# ['Country/Territory', 'Region', 'IMF', 'IMF', 'United Nations', 'United Nations', 'World Bank', 'World Bank'] 0
# 8
# ['Country/Territory', 'Region', 'IMF', 'IMF', 'United Nations', 'United Nations', 'World Bank', 'World Bank', 'Estimate'] 1
# ['Country/Territory', 'Region', 'IMF', 'IMF', 'United Nations', 'United Nations', 'World Bank', 'World Bank', 'Estimate', 'Year'] 1
# ['Country/Territory', 'Region', 'IMF', 'IMF', 'United Nations', 'United Nations', 'World Bank', 'World Bank', 'Estimate', 'Year', 'Estimate'] 1
# ['Country/Territory', 'Region', 'IMF', 'IMF', 'United Nations', 'United Nations', 'World Bank', 'World Bank', 'Estimate', 'Year', 'Estimate', 'Year'] 1
# ...

# %%
table[:10]
# Out:
# [[],
#  [],
#  ['United States',
#   'Americas',
#   '22,939,580',
#   '2021',
#   '21,433,226',
#   '2019',
#   '20,936,600',
#   '2020'],
#  ['China',
#   'Asia',
#   '16,862,979',
#   '2021',
#   '14,342,933',
#   '2019',
#   '14,722,731',
#   '2020'],
#  ['Japan',
#   'Asia',
#   '5,103,110',
#   '2021',
#   '5,082,465',
#   '2019',
#   '4,975,415',
#   '2020'],
#  ['Germany',
#   'Europe',
#   '4,230,172',
#   '2021',
#   '3,861,123',
#   '2019',
#   '3,806,060',
#   '2020'],
#  ['United Kingdom',
#   'Europe',
#   '3,108,416',
#   '2021',
#   '2,826,441',
#   '2019',
#   '2,707,744',
#   '2020'],
#  ['India',
#   'Asia',
#   '2,946,061',
#   '2021',
#   '2,891,582',
#   '2019',
#   '2,622,984',
#   '2020'],
#  ['France',
#   'Europe',
#   '2,940,428',
#   '2021',
#   '2,715,518',
#   '2019',
#   '2,603,004',
#   '2020'],
#  ['Italy',
#   'Europe',
#   '2,120,232',
#   '2021',
#   '2,003,576',
#   '2019',
#   '1,886,445',
#   '2020']]

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of countries by GDP (nominal) - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"6ab85a38-2a24-4e43-b6b4-2e95f7bd75f9","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_GDP_(nominal)","wgTitle":"List of countries by GDP (nominal)","wgCurRevisionId":1064422848,"wgRevisionId":1064422848,"wgArticleId":380845,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using the EasyTimeline extension","Articles with short description","Short d
# ...
